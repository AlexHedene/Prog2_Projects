# %% [markdown]
# # OpenMC: Scripting
#
# Please indicate your name below, since you will need to submit this notebook completed latest the day after the datalab.
#
# Don't forget to save your progress during the datalab to avoid any loss due to crashes.

# %%
name='Alexander Hedene'

# %% [markdown]
# **Note** you will need to run Jupyter from an environment where openMC is available in order to run this notebook!
#
# During the first openMC datalab, we have covered the basics, and covered how to write a basic input, how to run it and how to post-process the results. Today we go one step further and will explore the real power of the python API. Namely that we can automatize calculations simply by defining a function which creates the input for us. Then we can write loops and automatically update our model. For this we will use the `Model()` class of openMC. This basically means that instead of exporting all the details of the run into xml, openMC will take care of this, when we call the `.run()` method of the class.
#
# We will learn about
#
# - the built in criticality search functionality of openMC (which is a wrapper for the scipy.optimization methods).
# - write our own script to determine the void-coefficient change of the LWR pincell at various fuel to moderator ratio
# - will write a tally to investigate the fuel utilization factor and the resonance escape probability.
#
# Let's get started with doing the necessary imports!

# %%
import openmc
import openmc.model
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Experiment 1
#
# First we will calculate the boron concentration at which the k-infinity of the pincell is 1.2. For a finite core, of course usually we would like to know the critical boron content, but now we have reflective boundaries (ie. no leakage), so for the demonstration we aim for higher than 1.0 multiplication factor.
#
# First, we will define the `pincell()` function. The expressions inside this function are probably similar from the previous datalab. We only did some small changes:
# - we have decreased the number of particles per batch: although we will have a worse accuracy, but we will need to run this input several times, and it is not sustainable to spend the datalab with waiting for the calculations to finish
# - we have not included a numeric ID for the `Material()` instances. In this case openMC will increment the ID number. Since in these examples we do not use the IDs for anything, we can live without controlling it. (If we kept the ID, openMC would send a warning all the time that the ID was already in use. It is a warning, so not an error, but still annoying).
# - we have added a small amount of boron to the water (in reality boric acid is added to the water)
# - we have removed the calls to the `export_to_xml()` methods.
# - since we removed the tallies, we included `settings.output = {'tallies': False}` (this is to make sure that in case a 'tallies.xml' file is present from an other run it is not used)
# - finally, at the end we create an instance `model = openmc.model.Model(geom, mats, settings)` and return it.

# %%
def pincell(bppm):
    uo2 = openmc.Material(name="uo2",temperature=1200)
    # Adding nuclides to uo2
    uo2.add_nuclide('U235', 0.04)
    uo2.add_nuclide('U238', 0.96)
    uo2.add_nuclide('O16', 2.0)
    uo2.set_density('g/cm3', 10.5)


    #cladding
    zirconium = openmc.Material(name="zirconium",temperature=900)
    zirconium.add_element('Zr', 1.0)
    zirconium.set_density('g/cm3', 6.6)

    #coolant
    water = openmc.Material(name="h2o")
    water.add_nuclide('H1', 2.0)
    water.add_nuclide('O16', 1.0)
    water.set_density('g/cm3', 0.74)
    #THIS IS THE IMPORTANT NEW LINE COMPARED TO BEFORE!
    water.add_element('B', bppm*1e-6) 
    ###################################################
    water.add_s_alpha_beta('c_H_in_H2O')

    mats = openmc.Materials([uo2, zirconium, water])


    fuel_or = openmc.ZCylinder(r=0.41) #fuel cylinder with outer radius
    clad_ir = openmc.ZCylinder(r=0.42) #clad inner cylinder with inner radius
    clad_or = openmc.ZCylinder(r=0.45) #clad outer cylinder with outer radius

    fuel_region = -fuel_or                #inside the fuel cylinder
    gap_region = +fuel_or & -clad_ir      #outside of fuel cylinder and inside of clad inner cylinder
    clad_region = +clad_ir & -clad_or     #outside of clad inner cylinder and inside of clad outer cylinder

    fuel = openmc.Cell(name='fuel')
    fuel.fill = uo2
    fuel.region = fuel_region

    gap = openmc.Cell(name='air gap')
    gap.region = gap_region

    clad = openmc.Cell(name='clad')
    clad.fill = zirconium
    clad.region = clad_region

    pitch = 1.26
    #we define the x and y planes with boundary condition
    left = openmc.XPlane(x0=-pitch/2, boundary_type='reflective')
    right = openmc.XPlane(x0=pitch/2, boundary_type='reflective')
    bottom = openmc.YPlane(y0=-pitch/2, boundary_type='reflective')
    top = openmc.YPlane(y0=pitch/2, boundary_type='reflective')

    #outside of left and inside of right, outside of bottom, and inside of top and outside of clad outer cylinder
    water_region = +left & -right & +bottom & -top & +clad_or

    moderator = openmc.Cell(name='moderator')
    moderator.fill = water
    moderator.region = water_region

    root = openmc.Universe(cells=(fuel, gap, clad, moderator))

    geom = openmc.Geometry()
    geom.root_universe = root

    point = openmc.stats.Point((0, 0, 0))
    src = openmc.Source(space=point)

    settings = openmc.Settings()
    settings.source = src
    settings.batches = 100
    settings.inactive = 10
    settings.particles = 500
    settings.output = {'tallies': False}

    model = openmc.model.Model(geom, mats, settings)
    return model

# %% [markdown]
# Now we can perform a search for the boron concentration at which the multiplication factor is 1.2. This is a fairly similar root finding problem that we have done in datalab 5. In fact, if you look into the [source code](https://docs.openmc.org/en/stable/_modules/openmc/search.html#search_for_keff) of `openmc.search_for_keff` you will see that the function wraps the methods of scipy.optimize.
#
# We will need to pass as an input the function `pincell`, we can specify the lower and upper bound of the boron content to limit the interval of the search, and set the tolerance (ie. how accurate we want to be with the desired multiplication factor). The search will need some time, so while you wait you can start reading the next experiment!

# %%
os.system('rm *h5')
crit_ppm, guesses, keffs = openmc.search_for_keff(pincell, target=1.2, bracket=[2000., 3500.],
                                                  tol=1e-2, print_iterations=True)

print('Critical Boron Concentration: {:4.0f} ppm'.format(crit_ppm))
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13 13:37:36
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files will be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /root/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /root/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /root/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /root/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /root/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /root/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /root/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading H1 from /root/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /root/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /root/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading c_H_in_H2O from /root/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.30011
#         2/1    1.32888
#         3/1    1.15959
#         4/1    1.28333
#         5/1    1.22749
#         6/1    1.31838
#         7/1    1.30299
#         8/1    1.32199
#         9/1    1.28707
#        10/1    1.31131
#        11/1    1.19265
#        12/1    1.28437    1.23851 +/- 0.04586
#        13/1    1.40446    1.29383 +/- 0.06133
#        14/1    1.30239    1.29597 +/- 0.04342
#        15/1    1.24873    1.28652 +/- 0.03493
#        16/1    1.19172    1.27072 +/- 0.03261
#        17/1    1.25085    1.26788 +/- 0.02770
#        18/1    1.25813    1.26666 +/- 0.02402
#        19/1    1.32380    1.27301 +/- 0.02212
#        20/1    1.29927    1.27564 +/- 0.01996
#        21/1    1.16256    1.26536 +/- 0.02077
#        22/1    1.24852    1.26395 +/- 0.01901
#        23/1    1.26310    1.26389 +/- 0.01749
#        24/1    1.38037    1.27221 +/- 0.01821
#        25/1    1.29055    1.27343 +/- 0.01699
#        26/1    1.22684    1.27052 +/- 0.01616
#        27/1    1.28982    1.27165 +/- 0.01522
#        28/1    1.28911    1.27262 +/- 0.01438
#        29/1    1.22472    1.27010 +/- 0.01384
#        30/1    1.27401    1.27030 +/- 0.01313
#        31/1    1.16411    1.26524 +/- 0.01347
#        32/1    1.32264    1.26785 +/- 0.01311
#        33/1    1.19114    1.26452 +/- 0.01296
#        34/1    1.22302    1.26279 +/- 0.01253
#        35/1    1.25645    1.26253 +/- 0.01202
#        36/1    1.29516    1.26379 +/- 0.01162
#        37/1    1.25838    1.26359 +/- 0.01118
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.7456e-01 seconds
#    Reading cross sections          = 8.2916e-01 seconds
#  Total time in simulation          = 3.1990e-01 seconds
#    Time in transport only          = 2.8064e-01 seconds
#    Time in inactive batches        = 3.8959e-02 seconds
#    Time in active batches          = 2.8094e-01 seconds
#    Time synchronizing fission bank = 3.3276e-03 seconds
#      Sampling source sites         = 1.8160e-03 seconds
#      SEND/RECV source sites        = 3.9199e-04 seconds
#    Time accumulating tallies       = 2.7723e-05 seconds
#    Time writing statepoints        = 2.8372e-02 seconds
#  Total time for finalization       = 1.2220e-06 seconds
#  Total time elapsed                = 1.2974e+00 seconds
#  Calculation Rate (inactive)       = 128341 particles/second
#  Calculation Rate (active)         = 160178 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.26177 +/- 0.00619
#  k-effective (Track-length)  = 1.26218 +/- 0.00709
#  k-effective (Absorption)    = 1.25921 +/- 0.00484
#  Combined k-effective        = 1.25998 +/- 0.00454
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 1; Guess of 2.00e+03 produced a keff of 1.25998 +/- 0.00454
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13 13:37:38
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files will be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /root/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /root/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /root/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /root/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /root/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /root/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /root/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading H1 from /root/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /root/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /root/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading c_H_in_H2O from /root/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.17196
#         2/1    1.12901
#         3/1    1.11228
#         4/1    1.23351
#         5/1    1.04820
#         6/1    1.25109
#         7/1    1.20204
#         8/1    1.18166
#         9/1    1.15802
#        10/1    1.22166
#        11/1    1.12440
#        12/1    1.14408    1.13424 +/- 0.00984
#        13/1    1.13580    1.13476 +/- 0.00570
#        14/1    1.15305    1.13933 +/- 0.00610
#        15/1    1.15304    1.14207 +/- 0.00546
#        16/1    1.05210    1.12708 +/- 0.01564
#        17/1    1.18417    1.13524 +/- 0.01553
#        18/1    1.20485    1.14394 +/- 0.01602
#        19/1    1.09163    1.13812 +/- 0.01528
#        20/1    1.08740    1.13305 +/- 0.01458
#        21/1    1.14948    1.13455 +/- 0.01327
#        22/1    1.21633    1.14136 +/- 0.01390
#        23/1    1.06212    1.13527 +/- 0.01416
#        24/1    1.20942    1.14056 +/- 0.01414
#        25/1    1.11081    1.13858 +/- 0.01331
#        26/1    1.18547    1.14151 +/- 0.01280
#        27/1    1.14245    1.14157 +/- 0.01202
#        28/1    1.22383    1.14614 +/- 0.01222
#        29/1    1.25911    1.15208 +/- 0.01300
#        30/1    1.35645    1.16230 +/- 0.01601
#        31/1    1.20897    1.16452 +/- 0.01539
#        32/1    1.16496    1.16454 +/- 0.01468
#        33/1    1.25894    1.16865 +/- 0.01461
#        34/1    1.09689    1.16566 +/- 0.01431
#        35/1    1.25505    1.16923 +/- 0.01418
#        36/1    1.17799    1.16957 +/- 0.01363
#        37/1    1.08925    1.16659 +/- 0.01345
#        38/1    1.24544    1.16941 +/- 0.01326
#        39/1    1.21129    1.17085 +/- 0.01288
#        40/1    1.19394    1.17162 +/- 0.01246
#        41/1    1.22318    1.17329 +/- 0.01217
#        42/1    1.25929    1.17597 +/- 0.01209
#        43/1    1.21031    1.17701 +/- 0.01176
#        44/1    1.12767    1.17556 +/- 0.01150
#        45/1    1.13026    1.17427 +/- 0.01124
#        46/1    1.12255    1.17283 +/- 0.01102
#        47/1    1.12964    1.17167 +/- 0.01078
#        48/1    1.16685    1.17154 +/- 0.01049
#        49/1    1.08180    1.16924 +/- 0.01048
#        50/1    1.15962    1.16900 +/- 0.01021
#        51/1    1.16103    1.16880 +/- 0.00996
#        52/1    1.13238    1.16794 +/- 0.00976
#        53/1    1.09229    1.16618 +/- 0.00969
#        54/1    1.24272    1.16792 +/- 0.00963
#        55/1    1.15993    1.16774 +/- 0.00941
#        56/1    0.99361    1.16395 +/- 0.00996
#        57/1    1.08112    1.16219 +/- 0.00990
#        58/1    1.20020    1.16298 +/- 0.00972
#        59/1    1.07939    1.16128 +/- 0.00967
#        60/1    1.15890    1.16123 +/- 0.00948
#        61/1    1.28183    1.16359 +/- 0.00959
#        62/1    1.16297    1.16358 +/- 0.00940
#        63/1    1.11339    1.16263 +/- 0.00927
#        64/1    1.13530    1.16213 +/- 0.00911
#        65/1    1.16902    1.16225 +/- 0.00895
#        66/1    1.13010    1.16168 +/- 0.00880
#        67/1    1.10081    1.16061 +/- 0.00871
#        68/1    1.20777    1.16143 +/- 0.00860
#        69/1    1.22235    1.16246 +/- 0.00852
#        70/1    1.04496    1.16050 +/- 0.00860
#        71/1    1.12942    1.15999 +/- 0.00847
#        72/1    1.22325    1.16101 +/- 0.00840
#        73/1    1.12227    1.16040 +/- 0.00828
#        74/1    1.11478    1.15968 +/- 0.00819
#        75/1    1.15402    1.15960 +/- 0.00806
#        76/1    1.20430    1.16027 +/- 0.00796
#        77/1    1.11986    1.15967 +/- 0.00787
#        78/1    1.18083    1.15998 +/- 0.00776
#        79/1    1.07059    1.15869 +/- 0.00775
#        80/1    1.20816    1.15939 +/- 0.00767
#        81/1    1.07832    1.15825 +/- 0.00765
#        82/1    1.22214    1.15914 +/- 0.00760
#        83/1    1.19298    1.15960 +/- 0.00751
#        84/1    1.15783    1.15958 +/- 0.00740
#        85/1    1.07735    1.15848 +/- 0.00739
#        86/1    1.09923    1.15770 +/- 0.00733
#        87/1    1.17079    1.15787 +/- 0.00724
#        88/1    1.26217    1.15921 +/- 0.00727
#        89/1    1.19003    1.15960 +/- 0.00718
#        90/1    1.24234    1.16063 +/- 0.00717
#        91/1    1.19745    1.16109 +/- 0.00709
#        92/1    1.12597    1.16066 +/- 0.00702
#        93/1    1.19352    1.16106 +/- 0.00695
#        94/1    1.04567    1.15968 +/- 0.00700
#        95/1    1.14927    1.15956 +/- 0.00692
#        96/1    1.20109    1.16004 +/- 0.00685
#        97/1    1.22942    1.16084 +/- 0.00682
#        98/1    1.15517    1.16077 +/- 0.00674
#        99/1    1.17538    1.16094 +/- 0.00667
#       100/1    1.15632    1.16089 +/- 0.00660
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.3635e-01 seconds
#    Reading cross sections          = 3.9694e-01 seconds
#  Total time in simulation          = 2.5503e-01 seconds
#    Time in transport only          = 2.1715e-01 seconds
#    Time in inactive batches        = 2.2729e-02 seconds
#    Time in active batches          = 2.3230e-01 seconds
#    Time synchronizing fission bank = 2.2350e-03 seconds
#      Sampling source sites         = 1.8273e-03 seconds
#      SEND/RECV source sites        = 1.9543e-04 seconds
#    Time accumulating tallies       = 2.5866e-05 seconds
#    Time writing statepoints        = 2.5551e-02 seconds
#  Total time for finalization       = 1.2020e-06 seconds
#  Total time elapsed                = 6.9383e-01 seconds
#  Calculation Rate (inactive)       = 219981 particles/second
#  Calculation Rate (active)         = 193716 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1
#        69/1    1.11285    1.20582 +/- 0.00828
#        70/1    1.19641    1.20566 +/- 0.00815
#        71/1    1.25457    1.20646 +/- 0.00805
#        72/1    1.25178    1.20719 +/- 0.00795
#        73/1    1.04715    1.20465 +/- 0.00823
#        74/1    1.24398    1.20527 +/- 0.00812
#        75/1    1.20346    1.20524 +/- 0.00800
#        76/1    1.26047    1.20608 +/- 0.00792
#        77/1    1.32539    1.20786 +/- 0.00800
#        78/1    1.16128    1.20717 +/- 0.00791
#        79/1    1.16809    1.20661 +/- 0.00782
#        80/1    1.10209    1.20511 +/- 0.00785
#        81/1    1.09400    1.20355 +/- 0.00789
#        82/1    1.35441    1.20564 +/- 0.00806
#        83/1    1.04120    1.20339 +/- 0.00826
#        84/1    1.13315    1.20244 +/- 0.00820
#        85/1    1.34706    1.20437 +/- 0.00832
#        86/1    1.23470    1.20477 +/- 0.00822
#        87/1    1.15203    1.20409 +/- 0.00814
#        88/1    1.31526    1.20551 +/- 0.00816
#        89/1    1.19576    1.20539 +/- 0.00806
#        90/1    1.18213    1.20510 +/- 0.00796
#        91/1    1.24094    1.20554 +/- 0.00788
#        92/1    1.19562    1.20542 +/- 0.00778
#        93/1    1.12881    1.20449 +/- 0.00774
#        94/1    1.21372    1.20460 +/- 0.00765
#        95/1    1.22701    1.20487 +/- 0.00756
#        96/1    1.21732    1.20501 +/- 0.00748
#        97/1    1.31048    1.20623 +/- 0.00749
#        98/1    1.14910    1.20558 +/- 0.00743
#        99/1    1.20111    1.20553 +/- 0.00735
#       100/1    1.21571    1.20564 +/- 0.00727
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.2688e-01 seconds
#    Reading cross sections          = 3.7862e-01 seconds
#  Total time in simulation          = 2.7461e-01 seconds
#    Time in transport only          = 2.3695e-01 seconds
#    Time in inactive batches        = 2.5562e-02 seconds
#    Time in active batches          = 2.4905e-01 seconds
#    Time synchronizing fission bank = 2.2622e-03 seconds
#      Sampling source sites         = 1.8311e-03 seconds
#      SEND/RECV source sites        = 1.9944e-04 seconds
#    Time accumulating tallies       = 2.7594e-05 seconds
#    Time writing statepoints        = 2.8623e-02 seconds
#  Total time for finalization       = 1.4430e-06 seconds
#  Total time elapsed                = 7.0395e-01 seconds
#  Calculation Rate (inactive)       = 195604 particles/second
#  Calculation Rate (active)         = 180684 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.19660 +/- 0.00578
#  k-effective (Track-length)  = 1.20564 +/- 0.00727
#  k-effective (Absorption)    = 1.20273 +/- 0.00428
#  Combined k-effective        = 1.20184 +/- 0.00413
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 4; Guess of 3.12e+03 produced a keff of 1.20184 +/- 0.00413
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13 13:37:40
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files will be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /root/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /root/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /root/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /root/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /root/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /root/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /root/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading H1 from /root/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /root/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /root/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading c_H_in_H2O from /root/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.19575
#         2/1    1.17309
#         3/1    1.13509
#         4/1    1.23302
#         5/1    1.20464
#         6/1    1.23675
#         7/1    1.11153
#         8/1    1.14732
#         9/1    1.11776
#        10/1    1.20846
#        11/1    1.14203
#        12/1    1.10996    1.12599 +/- 0.01603
#        13/1    1.26012    1.17070 +/- 0.04566
#        14/1    1.23978    1.18797 +/- 0.03661
#        15/1    1.22636    1.19565 +/- 0.02938
#        16/1    1.27031    1.20809 +/- 0.02702
#        79/1    1.14328    1.17594 +/- 0.00816
#        80/1    1.14504    1.17550 +/- 0.00805
#        81/1    1.16468    1.17535 +/- 0.00794
#        82/1    1.17959    1.17541 +/- 0.00783
#        83/1    1.16942    1.17533 +/- 0.00772
#        84/1    1.12308    1.17462 +/- 0.00765
#        85/1    1.23187    1.17538 +/- 0.00759
#        86/1    1.32419    1.17734 +/- 0.00774
#        87/1    1.18421    1.17743 +/- 0.00764
#        88/1    1.28017    1.17875 +/- 0.00765
#        89/1    1.14387    1.17831 +/- 0.00757
#        90/1    1.06533    1.17689 +/- 0.00760
#        91/1    1.21099    1.17731 +/- 0.00752
#        92/1    1.10064    1.17638 +/- 0.00749
#        93/1    1.19488    1.17660 +/- 0.00740
#        94/1    1.16710    1.17649 +/- 0.00731
#        95/1    1.14041    1.17607 +/- 0.00724
#        96/1    1.24583    1.17688 +/- 0.00720
#        97/1    1.09883    1.17598 +/- 0.00717
#        98/1    1.17812    1.17600 +/- 0.00709
#        99/1    1.16149    1.17584 +/- 0.00701
#       100/1    1.17781    1.17586 +/- 0.00693
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.2479e-01 seconds
#    Reading cross sections          = 3.7706e-01 seconds
#  Total time in simulation          = 2.5890e-01 seconds
#    Time in transport only          = 2.3018e-01 seconds
#    Time in inactive batches        = 2.4291e-02 seconds
#    Time in active batches          = 2.3460e-01 seconds
#    Time synchronizing fission bank = 2.2457e-03 seconds
#      Sampling source sites         = 1.8349e-03 seconds
#      SEND/RECV source sites        = 1.9804e-04 seconds
#    Time accumulating tallies       = 2.8373e-05 seconds
#    Time writing statepoints        = 1.9776e-02 seconds
#  Total time for finalization       = 1.2530e-06 seconds
#  Total time elapsed                = 6.8618e-01 seconds
#  Calculation Rate (inactive)       = 205834 particles/second
#  Calculation Rate (active)         = 191813 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.16997 +/- 0.00547
#  k-effective (Track-length)  = 1.17586 +/- 0.00693
#  k-effective (Absorption)    = 1.17351 +/- 0.00467
#  Combined k-effective        = 1.17303 +/- 0.00443
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 5; Guess of 3.31e+03 produced a keff of 1.17303 +/- 0.00443
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13 13:37:41
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files will be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /root/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /root/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /root/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /root/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /root/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /root/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /root/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading H1 from /root/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /root/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /root/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading c_H_in_H2O from /root/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.22345
#         2/1    1.24494
#         3/1    1.18273
#         4/1    1.19176
#         5/1    1.15740
#         6/1    1.28071
#         7/1    1.25488
#         8/1    1.16792
#         9/1    1.14736
#        10/1    1.11702
#        11/1    1.12902
#        12/1    1.27113    1.20007 +/- 0.07106
#        13/1    1.17798    1.19271 +/- 0.04168
#        14/1    1.28758    1.21643 +/- 0.03783
#        15/1    1.20259    1.21366 +/- 0.02943
#        16/1    1.21939    1.21462 +/- 0.02405
#        17/1    1.17205    1.20853 +/- 0.02122
#        18/1    1.15990    1.20246 +/- 0.01935
#        19/1    1.22629    1.20510 +/- 0.01727
#        20/1    1.11481    1.19607 +/- 0.01790
#        21/1    1.23962    1.20003 +/- 0.01666
#        22/1    1.18826    1.19905 +/- 0.01524
#        23/1    1.23876    1.20211 +/- 0.01435
#        24/1    1.17475    1.20015 +/- 0.01343
#        25/1    1.24878    1.20339 +/- 0.01292
#        26/1    1.18361    1.20216 +/- 0.01214
#        27/1    1.12393    1.19756 +/- 0.01230
#        28/1    1.06240    1.19005 +/- 0.01382
#        29/1    1.10845    1.18575 +/- 0.01376
#        30/1    1.11747    1.18234 +/- 0.01349
#        31/1    1.16400    1.18146 +/- 0.01286
#        32/1    1.19935    1.18228 +/- 0.01229
# ...
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13
#        63/1    1.22435    1.19588 +/- 0.01043
#        64/1    1.11620    1.19440 +/- 0.01034
#        65/1    1.29730    1.19627 +/- 0.01032
#        66/1    1.22901    1.19686 +/- 0.01015
#        67/1    1.14826    1.19601 +/- 0.01001
#        68/1    1.35778    1.19879 +/- 0.01022
#        69/1    1.05838    1.19641 +/- 0.01033
#        70/1    1.09535    1.19473 +/- 0.01029
#        71/1    1.11722    1.19346 +/- 0.01020
#        72/1    1.11195    1.19214 +/- 0.01012
#        73/1    1.18317    1.19200 +/- 0.00996
#        74/1    1.13603    1.19113 +/- 0.00984
#        75/1    1.26339    1.19224 +/- 0.00975
#        76/1    1.19425    1.19227 +/- 0.00960
#        77/1    1.23712    1.19294 +/- 0.00948
#        78/1    1.19523    1.19297 +/- 0.00934
#        79/1    1.15558    1.19243 +/- 0.00922
#        80/1    1.13752    1.19165 +/- 0.00912
#        81/1    1.13508    1.19085 +/- 0.00903
#        82/1    1.07052    1.18918 +/- 0.00906
#        83/1    1.11559    1.18817 +/- 0.00899
#        84/1    1.15346    1.18770 +/- 0.00888
#        85/1    1.17970    1.18759 +/- 0.00876
#        86/1    1.12577    1.18678 +/- 0.00868
#        87/1    1.16947    1.18656 +/- 0.00857
#        88/1    1.18200    1.18650 +/- 0.00846
#        89/1    1.13129    1.18580 +/- 0.00838
#        90/1    1.20376    1.18602 +/- 0.00828
#        91/1    1.15687    1.18566 +/- 0.00819
#        92/1    1.11286    1.18478 +/- 0.00814
#        93/1    1.16651    1.18456 +/- 0.00804
#        94/1    1.10124    1.18356 +/- 0.00801
#        95/1    1.18144    1.18354 +/- 0.00791
#        96/1    1.24028    1.18420 +/- 0.00785
#        97/1    1.25887    1.18506 +/- 0.00780
#        98/1    1.17224    1.18491 +/- 0.00771
#        99/1    1.32544    1.18649 +/- 0.00779
#       100/1    1.29137    1.18766 +/- 0.00779
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.1810e-01 seconds
#    Reading cross sections          = 3.7907e-01 seconds
#  Total time in simulation          = 2.7150e-01 seconds
#    Time in transport only          = 2.3246e-01 seconds
#    Time in inactive batches        = 2.4996e-02 seconds
#    Time in active batches          = 2.4651e-01 seconds
#    Time synchronizing fission bank = 2.2526e-03 seconds
#      Sampling source sites         = 1.8222e-03 seconds
#      SEND/RECV source sites        = 2.0300e-04 seconds
#    Time accumulating tallies       = 3.1109e-05 seconds
#    Time writing statepoints        = 2.9881e-02 seconds
#  Total time for finalization       = 1.4730e-06 seconds
#  Total time elapsed                = 6.9209e-01 seconds
#  Calculation Rate (inactive)       = 200031 particles/second
#  Calculation Rate (active)         = 182550 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.19461 +/- 0.00621
#  k-effective (Track-length)  = 1.18766 +/- 0.00779
#  k-effective (Absorption)    = 1.19718 +/- 0.00469
#  Combined k-effective        = 1.19585 +/- 0.00449
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 7; Guess of 3.17e+03 produced a keff of 1.19585 +/- 0.00449
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13 13:37:43
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files will be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /root/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /root/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /root/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /root/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /root/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /root/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /root/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading H1 from /root/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading B10 from /root/endfb-vii.1-hdf5/neutron/B10.h5
#  Reading B11 from /root/endfb-vii.1-hdf5/neutron/B11.h5
#  Reading c_H_in_H2O from /root/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1
#        73/1    1.23407    1.20044 +/- 0.00682
#        74/1    1.11453    1.19910 +/- 0.00685
#        75/1    1.27826    1.20032 +/- 0.00685
#        76/1    1.23114    1.20078 +/- 0.00676
#        77/1    1.30588    1.20235 +/- 0.00684
#        78/1    1.07247    1.20044 +/- 0.00701
#        79/1    1.10494    1.19906 +/- 0.00704
#        80/1    1.30222    1.20053 +/- 0.00709
#        81/1    1.15545    1.19990 +/- 0.00702
#        82/1    1.13828    1.19904 +/- 0.00698
#        83/1    1.26101    1.19989 +/- 0.00693
#        84/1    1.26703    1.20080 +/- 0.00690
#        85/1    1.09303    1.19936 +/- 0.00696
#        86/1    1.17538    1.19905 +/- 0.00687
#        87/1    1.22877    1.19943 +/- 0.00679
#        88/1    1.26954    1.20033 +/- 0.00676
#        89/1    1.31725    1.20181 +/- 0.00684
#        90/1    1.27494    1.20272 +/- 0.00682
#        91/1    1.23526    1.20313 +/- 0.00674
#        92/1    1.28344    1.20411 +/- 0.00673
#        93/1    1.31748    1.20547 +/- 0.00679
#        94/1    1.23375    1.20581 +/- 0.00672
#        95/1    1.29399    1.20685 +/- 0.00672
#        96/1    1.11271    1.20575 +/- 0.00673
#        97/1    1.15972    1.20522 +/- 0.00667
#        98/1    1.21068    1.20528 +/- 0.00660
#        99/1    1.14596    1.20462 +/- 0.00655
#       100/1    1.13107    1.20380 +/- 0.00653
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.2200e-01 seconds
#    Reading cross sections          = 3.7505e-01 seconds
#  Total time in simulation          = 2.7117e-01 seconds
#    Time in transport only          = 2.3270e-01 seconds
#    Time in inactive batches        = 2.3232e-02 seconds
#    Time in active batches          = 2.4794e-01 seconds
#    Time synchronizing fission bank = 2.2632e-03 seconds
#      Sampling source sites         = 1.8445e-03 seconds
#      SEND/RECV source sites        = 1.9324e-04 seconds
#    Time accumulating tallies       = 2.8010e-05 seconds
#    Time writing statepoints        = 2.9108e-02 seconds
#  Total time for finalization       = 1.5130e-06 seconds
#  Total time elapsed                = 6.9543e-01 seconds
#  Calculation Rate (inactive)       = 215222 particles/second
#  Calculation Rate (active)         = 181495 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.20206 +/- 0.00584
#  k-effective (Track-length)  = 1.20380 +/- 0.00653
#  k-effective (Absorption)    = 1.19655 +/- 0.00491
#  Combined k-effective        = 1.19909 +/- 0.00431
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 8; Guess of 3.15e+03 produced a keff of 1.19909 +/- 0.00431
# Critical Boron Concentration: 3148 ppm

# %% [markdown]
# We can visualize the guesses by the optimization algorithm, and see how the boron content converged to the correct amount.

# %%
plt.figure()
for g,k in zip(guesses,keffs):
    plt.scatter(g,k.nominal_value,color='k')
plt.xlabel('boron content (ppm)')
plt.ylabel('k-inf')
plt.scatter(crit_ppm,1.2,color='r')
plt.show()

# %% [markdown]
# ## Experiment 2
#
# During the lectures we have learnt about the reactivity feedback coefficients. Today we are going to investigate the void coefficient for various moderator to fuel ratios. The moderator to fuel ratio can be defined in the rectangular pincell as
#
# $$mfr=\frac{p^2-r_{clad}^2\pi}{r_{fuel}^2\pi}$$
#
# can be simply modified by changing the pitch $p$.
#
# The void constant of the fuel can be modified by changing the density of the coolant. We can use the following simple relationship:
#
# $$\rho_{coolant}=\rho_0(1-void[\%]/100)$$
#
# where $\rho_0=0.74$ g/cm3. In practice, of course we will never obtain a zero density even for a fully voided core. Also, it is worth mentioning that void levels investigated here are never reached in normal operations for a PWR, but are however the nominal levels for a BWR. Nevertheless, the goal of the exercise is not to investigate exact reactor operation scenarios, rather to provide a physicist insight for understanding how significantly lowering the density of the moderator affects the multiplication factor.
#
# First create a `pincell()` function where the user can modify the pitch and the void content. The function should return a `Model()` object. (You do not need to include boron in the coolant for this exercise).

# %%
def pincell(pitch,void):
    uo2 = openmc.Material(name="uo2",temperature=1200)
    # Adding nuclides to uo2
    uo2.add_nuclide('U235', 0.04)
    uo2.add_nuclide('U238', 0.96)
    uo2.add_nuclide('O16', 2.0)
    uo2.set_density('g/cm3', 10.5)


    #cladding
    zirconium = openmc.Material(name="zirconium",temperature=900)
    zirconium.add_element('Zr', 1.0)
    zirconium.set_density('g/cm3', 6.6)

    #coolant
    water = openmc.Material(name="h2o")
    water.add_nuclide('H1', 2.0)
    water.add_nuclide('O16', 1.0)
    void_density = 0.74*(1-void/100)
    water.set_density('g/cm3', void_density)
    water.add_s_alpha_beta('c_H_in_H2O')

    mats = openmc.Materials([uo2, zirconium, water])


    fuel_or = openmc.ZCylinder(r=0.41) #fuel cylinder with outer radius
    clad_ir = openmc.ZCylinder(r=0.42) #clad inner cylinder with inner radius
    clad_or = openmc.ZCylinder(r=0.45) #clad outer cylinder with outer radius

    fuel_region = -fuel_or                #inside the fuel cylinder
    gap_region = +fuel_or & -clad_ir      #outside of fuel cylinder and inside of clad inner cylinder
    clad_region = +clad_ir & -clad_or     #outside of clad inner cylinder and inside of clad outer cylinder

    fuel = openmc.Cell(name='fuel')
    fuel.fill = uo2
    fuel.region = fuel_region

    gap = openmc.Cell(name='air gap')
    gap.region = gap_region

    clad = openmc.Cell(name='clad')
    clad.fill = zirconium
    clad.region = clad_region

    # pitch = 1.26
    #we define the x and y planes with boundary condition
    left = openmc.XPlane(x0=-pitch/2, boundary_type='reflective')
    right = openmc.XPlane(x0=pitch/2, boundary_type='reflective')
    bottom = openmc.YPlane(y0=-pitch/2, boundary_type='reflective')
    top = openmc.YPlane(y0=pitch/2, boundary_type='reflective')

    #outside of left and inside of right, outside of bottom, and inside of top and outside of clad outer cylinder
    water_region = +left & -right & +bottom & -top & +clad_or

    moderator = openmc.Cell(name='moderator')
    moderator.fill = water
    moderator.region = water_region

    root = openmc.Universe(cells=(fuel, gap, clad, moderator))

    geom = openmc.Geometry()
    geom.root_universe = root

    point = openmc.stats.Point((0, 0, 0))
    src = openmc.Source(space=point)

    settings = openmc.Settings()
    settings.source = src
    settings.batches = 100
    settings.inactive = 10
    settings.particles = 500
    settings.output = {'tallies': False}

    model = openmc.model.Model(geom, mats, settings)
    return model

# %% [markdown]
# If a model is created with the pincell, it can be run with openMC with
#
# ```python
#     mod = pincell(1.26,0.0)
#     output = mod.run()
# ```
#
# where the `output` variable will contain the path to the state point file.
#
# Now we will call this function in a loop for several pitch values and then as a nested loop for three void values at each moderator to fuel ratio. Since the code will create the statepoint files with the same name, make sure that you store the quantity of interest (for example in arrays) before overwriting the output. At each moderator to fuel ratio you can perform a fit to estimate the void-coefficient (it can be a linear fit, considering that we will have only three values to fit for).
#
# Note that in case the computation seems to be slow, you should not use more than 500 particles per batch (you should get reasonably good results with 500 particles as well).
#
# Reminder: the statepoint files can be read with `sp = openmc.StatePoint(pathtofile)`, and the multiplication factor accessed with `sp.keff.nominal_value`.

# %%
from scipy.optimize import curve_fit

os.system('rm *h5')

pitch=[0.95,1.05,1.15,1.25,1.35,1.45,1.55,1.65,1.75,1.85,1.95,2.05]#,2.15,2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95]
void=[0,25,50]

#initialize lists to store results
void_constants = []
k_eff_constants = []
for pi in pitch:
    #initialize list to store keff values
    k_eff_values = []
    for v in void:
        #your code to call the pincell, run it, and store the k-effective comes here
        mod = pincell(pi, v)
        output = mod.run()
        sp = openmc.StatePoint('statepoint.100.h5')
        k_eff_values.append(sp.keff.nominal_value)

        os.system('rm %s'%output)
        os.system('rm summary.h5')
        
    #your code to estimate the void-coefficient from a linear fit. and to store the data
    k_eff_constants.append(k_eff_values)
    p,_ = curve_fit(lambda x,k,m: k*x + m, void, k_eff_values)
    void_constants.append(p[0])
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13 14:13:15
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files will be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /root/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /root/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /root/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /root/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /root/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /root/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /root/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading H1 from /root/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading c_H_in_H2O from /root/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.15823
#         2/1    1.12234
#         3/1    1.02421
#         4/1    0.96270
#         5/1    1.19884
#         6/1    1.09263
#         7/1    1.01968
#         8/1    1.09463
#         9/1    1.05243
#        10/1    1.06598
#        11/1    1.08367
#        12/1    1.10481    1.09424 +/- 0.01057
#        13/1    0.98587    1.05812 +/- 0.03663
#        14/1    1.12007    1.07360 +/- 0.03018
#        15/1    0.96144    1.05117 +/- 0.03240
#        16/1    0.99952    1.04256 +/- 0.02782
#        17/1    0.94860    1.02914 +/- 0.02707
#        18/1    1.11764    1.04020 +/- 0.02593
#        19/1    1.13462    1.05069 +/- 0.02516
#        20/1    1.02677    1.04830 +/- 0.02263
#        21/1    1.05340    1.04877 +/- 0.02047
#        22/1    1.02231    1.04656 +/- 0.01882
#        23/1    1.15890    1.05520 +/- 0.01935
#        24/1    1.24312    1.06862 +/- 0.02238
#        25/1    1.12271    1.07223 +/- 0.02115
#        26/1    1.02841    1.06949 +/- 0.01997
#        27/1    1.05489    1.06863 +/- 0.01878
#        28/1    1.11391    1.07115 +/- 0.01788
#        29/1    1.05080    1.07008 +/- 0.01695
#        30/1    1.03159    1.06815 +/- 0.01619
#        31/1    1.07968    1.06870 +/- 0.01541
#        32/1    1.28788    1.07866 +/- 0.01775
#        33/1    1.08430    1.07891 +/- 0.01697
#        34/1    1.05916    1.07809 +/- 0.01627
#        35/1    1.04035    1.07658 +/- 0.01567
#        36/1    1.17200    1.08025 +/- 0.01550
#        37/1    1.03709    1.07865 +/- 0.01500
#        38/1    1.12396    1.08027 +/- 0.01454
#        39/1    1.06833    1.07986 +/- 0.01404
#        40/1    1.04878    1.07882 +/- 0.01360
#        41/1    1.07796    1.07879 +/- 0.01316
#        42/1    1.09467    1.07929 +/- 0.01275
#        43/1    1.06748    1.07893 +/- 0.01236
#        44/1    1.14011    1.08073 +/- 0.01213
#        45/1    1.15529    1.08286 +/- 0.01197
#        46/1    1.13919    1.08442 +/- 0.01173
#        47/1    1.13011    1.08566 +/- 0.01148
#        48/1    1.10222    1.08610 +/- 0.01118
#        49/1    1.12117    1.08699 +/- 0.01093
#        50/1    1.02246    1.08538 +/- 0.01077
#        51/1    1.07526    1.08513 +/- 0.01051
#        64/1    1.00995    1.00856 +/- 0.00800
#        65/1    0.91446    1.00685 +/- 0.00803
#        66/1    1.00352    1.00679 +/- 0.00789
#        67/1    0.99828    1.00664 +/- 0.00775
#        68/1    0.85778    1.00407 +/- 0.00804
#        69/1    1.25516    1.00833 +/- 0.00897
#        70/1    0.94111    1.00721 +/- 0.00889
#        71/1    1.07869    1.00838 +/- 0.00883
#        72/1    0.96477    1.00767 +/- 0.00871
#        73/1    0.93685    1.00655 +/- 0.00864
#        74/1    1.09630    1.00795 +/- 0.00862
#        75/1    1.08189    1.00909 +/- 0.00856
#        76/1    0.85211    1.00671 +/- 0.00876
#        77/1    1.03120    1.00708 +/- 0.00864
#        78/1    0.95777    1.00635 +/- 0.00854
#        79/1    1.03989    1.00684 +/- 0.00843
#        80/1    1.06434    1.00766 +/- 0.00835
#        81/1    1.03846    1.00809 +/- 0.00824
#        82/1    1.01711    1.00822 +/- 0.00813
#        83/1    1.12460    1.00981 +/- 0.00817
#        84/1    0.91889    1.00858 +/- 0.00816
#        85/1    1.07494    1.00947 +/- 0.00809
#        86/1    1.03388    1.00979 +/- 0.00799
#        87/1    1.04343    1.01023 +/- 0.00790
#        88/1    1.08740    1.01122 +/- 0.00786
#        89/1    1.07960    1.01208 +/- 0.00781
#        90/1    1.01853    1.01216 +/- 0.00771
#        91/1    0.95139    1.01141 +/- 0.00765
#        92/1    1.04439    1.01181 +/- 0.00757
#        93/1    1.13348    1.01328 +/- 0.00762
#        94/1    0.94230    1.01244 +/- 0.00758
#        95/1    1.07653    1.01319 +/- 0.00752
#        96/1    1.03106    1.01340 +/- 0.00744
#        97/1    1.00054    1.01325 +/- 0.00736
#        98/1    1.11426    1.01440 +/- 0.00736
#        99/1    0.93561    1.01351 +/- 0.00733
#       100/1    1.05646    1.01399 +/- 0.00727
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.0433e-01 seconds
#    Reading cross sections          = 3.5836e-01 seconds
#  Total time in simulation          = 4.1752e-01 seconds
#    Time in transport only          = 3.8826e-01 seconds
#    Time in inactive batches        = 4.0637e-02 seconds
#    Time in active batches          = 3.7688e-01 seconds
#    Time synchronizing fission bank = 2.2947e-03 seconds
#      Sampling source sites         = 1.8691e-03 seconds
#      SEND/RECV source sites        = 1.8654e-04 seconds
#    Time accumulating tallies       = 2.6098e-05 seconds
#    Time writing statepoints        = 2.0051e-02 seconds
#  Total time for finalization       = 1.2930e-06 seconds
#  Total time elapsed                = 8.2430e-01 seconds
#  Calculation Rate (inactive)       = 123042 particles/second
#  Calculation Rate (active)         = 119401 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.01267 +/- 0.00623
#  k-effective (Track-length)  = 1.01399 +/- 0.00727
#  k-effective (Absorption)    = 1.01042 +/- 0.00473
#  Combined k-effective        = 1.01088 +/- 0.00440
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13 14:13:17
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files will be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /root/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /root/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /root/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /root/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /root/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /root/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /root/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading H1 from /root/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading c_H_in_H2O from /root/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1
#        87/1    1.14628    1.24204 +/- 0.00833
#        88/1    1.29021    1.24266 +/- 0.00825
#        89/1    1.23336    1.24254 +/- 0.00814
#        90/1    1.28362    1.24305 +/- 0.00806
#        91/1    1.09942    1.24128 +/- 0.00815
#        92/1    1.16514    1.24035 +/- 0.00810
#        93/1    1.26809    1.24069 +/- 0.00801
#        94/1    1.20558    1.24027 +/- 0.00793
#        95/1    1.30555    1.24104 +/- 0.00787
#        96/1    1.22775    1.24088 +/- 0.00778
#        97/1    1.16695    1.24003 +/- 0.00774
#        98/1    1.41173    1.24198 +/- 0.00789
#        99/1    1.06132    1.23995 +/- 0.00806
#       100/1    1.27928    1.24039 +/- 0.00799
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.9437e-01 seconds
#    Reading cross sections          = 3.4833e-01 seconds
#  Total time in simulation          = 3.4755e-01 seconds
#    Time in transport only          = 3.0969e-01 seconds
#    Time in inactive batches        = 3.2632e-02 seconds
#    Time in active batches          = 3.1492e-01 seconds
#    Time synchronizing fission bank = 2.4120e-03 seconds
#      Sampling source sites         = 1.9668e-03 seconds
#      SEND/RECV source sites        = 2.0731e-04 seconds
#    Time accumulating tallies       = 2.6067e-05 seconds
#    Time writing statepoints        = 2.8311e-02 seconds
#  Total time for finalization       = 1.2420e-06 seconds
#  Total time elapsed                = 7.4436e-01 seconds
#  Calculation Rate (inactive)       = 153222 particles/second
#  Calculation Rate (active)         = 142895 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.23601 +/- 0.00583
#  k-effective (Track-length)  = 1.24039 +/- 0.00799
#  k-effective (Absorption)    = 1.23127 +/- 0.00505
#  Combined k-effective        = 1.23166 +/- 0.00461
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13 14:13:19
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files will be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /root/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /root/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /root/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /root/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /root/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /root/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /root/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading H1 from /root/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading c_H_in_H2O from /root/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.08846
#         2/1    1.03959
#         3/1    1.14295
#         4/1    1.04850
#         5/1    1.19881
#         6/1    1.12544
#         7/1    1.13728
#         8/1    1.13908
#         9/1    1.16747
#        10/1    1.19652
#        11/1    1.10742
#        12/1    1.04031    1.07386 +/- 0.03356
#        13/1    1.04992    1.06588 +/- 0.02095
#        14/1    1.16304    1.09017 +/- 0.02845
#        15/1    1.15930    1.10400 +/- 0.02602
#        16/1    1.17925    1.11654 +/- 0.02467
#        17/1    1.12876    1.11829 +/- 0.02092
#        18/1    1.18303    1.12638 +/- 0.01984
#        19/1    1.19884    1.13443 +/- 0.01926
#        20/1    1.10652    1.13164 +/- 0.01745
#        21/1    1.15217    1.13351 +/- 0.01590
#        22/1    1.15177    1.13503 +/- 0.01459
#        23/1    1.20656    1.14053 +/- 0.01451
#        24/1    1.20527    1.14515 +/- 0.01420
#        25/1    1.18695    1.14794 +/- 0.01351
#        26/1    1.20039    1.15122 +/- 0.01306
#        27/1    1.21565    1.15501 +/- 0.01284
#        28/1    1.11408    1.15274 +/- 0.01232
#        29/1    1.08591    1.14922 +/- 0.01217
#        30/1    1.16210    1.14986 +/- 0.01156
#        31/1    1.05643    1.14541 +/- 0.01186
#        32/1    1.23012    1.14926 +/- 0.01195
#        33/1    1.14479    1.14907 +/- 0.01142
#        34/1    1.05538    1.14517 +/- 0.01161
#        35/1    1.11570    1.14399 +/- 0.01120
#        36/1    1.12070    1.14309 +/- 0.01080
#        74/1    1.40803    1.46023 +/- 0.00891
#        75/1    1.46737    1.46034 +/- 0.00878
#        76/1    1.45244    1.46022 +/- 0.00864
#        77/1    1.55148    1.46159 +/- 0.00862
#        78/1    1.39498    1.46061 +/- 0.00855
#        79/1    1.44754    1.46042 +/- 0.00843
#        80/1    1.47581    1.46064 +/- 0.00831
#        81/1    1.46940    1.46076 +/- 0.00819
#        82/1    1.45143    1.46063 +/- 0.00808
#        83/1    1.46438    1.46068 +/- 0.00797
#        84/1    1.46750    1.46077 +/- 0.00786
#        85/1    1.64757    1.46326 +/- 0.00814
#        86/1    1.45100    1.46310 +/- 0.00804
#        87/1    1.41563    1.46249 +/- 0.00796
#        88/1    1.45807    1.46243 +/- 0.00785
#        89/1    1.20195    1.45913 +/- 0.00843
#        90/1    1.39481    1.45833 +/- 0.00836
#        91/1    1.52403    1.45914 +/- 0.00830
#        92/1    1.57353    1.46053 +/- 0.00831
#        93/1    1.44326    1.46033 +/- 0.00821
#        94/1    1.52738    1.46112 +/- 0.00815
#        95/1    1.47955    1.46134 +/- 0.00806
#        96/1    1.37120    1.46029 +/- 0.00803
#        97/1    1.51653    1.46094 +/- 0.00797
#        98/1    1.41245    1.46039 +/- 0.00790
#        99/1    1.56364    1.46155 +/- 0.00789
#       100/1    1.40516    1.46092 +/- 0.00783
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8165e-01 seconds
#    Reading cross sections          = 3.4606e-01 seconds
#  Total time in simulation          = 2.9000e-01 seconds
#    Time in transport only          = 2.6123e-01 seconds
#    Time in inactive batches        = 2.2868e-02 seconds
#    Time in active batches          = 2.6714e-01 seconds
#    Time synchronizing fission bank = 2.3291e-03 seconds
#      Sampling source sites         = 1.8899e-03 seconds
#      SEND/RECV source sites        = 2.0225e-04 seconds
#    Time accumulating tallies       = 2.7232e-05 seconds
#    Time writing statepoints        = 1.9461e-02 seconds
#  Total time for finalization       = 1.5730e-06 seconds
#  Total time elapsed                = 6.7678e-01 seconds
#  Calculation Rate (inactive)       = 218645 particles/second
#  Calculation Rate (active)         = 168453 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.46662 +/- 0.00690
#  k-effective (Track-length)  = 1.46092 +/- 0.00783
#  k-effective (Absorption)    = 1.47159 +/- 0.00422
#  Combined k-effective        = 1.47036 +/- 0.00422
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %% [markdown]
# Alright, now we have the k-eigenvalue for several pitch and void values, and we have the void coefficient at several pitch values. It is time to visualize them somehow. Try to create a figure which shows the void coefficient vs the moderator to fuel ratio and an other figure which shows the k-eigenvalue vs the moderator to fuel ratio for each void levels.
#
# Conclude your findings: how would you design a reactor core? which moderator to fuel ratio would you select?

# %%
import numpy as np
mfr = (np.array(pitch)**2 - 0.45**2*np.pi)/(0.41**2*np.pi)

plt.figure()
#your code comes here to visualize the void coefficient vs moderator to fuel ratio
plt.plot(mfr, np.array(void_constants)/100) # Rewrite from percentage to decimal and giving it in 
plt.xlabel("mfr")
plt.ylabel("void coefficiant")
plt.show()

plt.figure()
#your code comes here to visualize the k-eigenvalue vs moderator to fuel ratio
columns = list(zip(*k_eff_constants))
for i in [0,1,2]:
    plt.plot(mfr, columns[i], label=f'void = {void[i]}%')
    plt.xlabel("mfr")
    plt.ylabel("k_eff")

plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
# The void coefficient starts negative for small mfr and increases. At around 5-6 mfr it is 0 and after that in is posetive. This means that reactivity decreases for lower mfr values with increased void which is good for safety.
#
# For the keff value, all keff increases with mfr and peaks at around mfr = 5. With an increased void, the keff is lower for the same mfr values. One thing to notice is that the void = 0 dips at very large mfr values where the other two, 25 and 50, increases even more.

# %% [markdown]
# ## Experiment 3
#
# Wow, we saw some interesting curve there, the k-infinity first increased with increasing the pitch and then it started to to decrease. Intuitively one expects that there are two competing physical phenonema at play here. And our intuition is correct. If you remember the 4-factor formula, there were two quantities which are of interest for us now to figure out why does the k-infinity change like this with the increasing pitch. And these two quantities are:
#
# **Resonance escape probability**: probability for fast neutrons to slow-down to thermal energies without being absorbed in the resonance region of absorbers
#
# $$p=1-\frac{\int_{V_{f}} \int_{\sim 5kT}^\infty \Sigma_a(r,E)\phi(r,E)dVdE}{\int_{V_{f}} \int_0^{\infty} \nu(E)\Sigma_f(r,E)\phi(r,E)dVdE}$$
#
#
# **Thermal utilization factor**: the ratio of the number of thermal neutrons absorbed in the fuel and the number of thermal neutrons absorbed in all materials
#
# $$f=\frac{\int_{V_{f}} \int_0^{\sim 5kT} \Sigma_a(r,E)\phi(r,E)dVdE}{\int_{V_{t}} \int_0^{\sim 5kT} \Sigma_a(r,E)\phi(r,E)dVdE}$$
#
# The nominators and the denominators look like the expressions we used to define the tallies. The "scores" here are absorption, and nu-fission and the filters are the energy bounds and the spatial regions. So let's add these tallies to our `pincell()` function (for the tallies we will need to fix the ID, since we will refer to them later):

# %%
def pincell(pitch):
    uo2 = openmc.Material(name="uo2",temperature=1200)
    # Adding nuclides to uo2
    uo2.add_nuclide('U235', 0.04)
    uo2.add_nuclide('U238', 0.96)
    uo2.add_nuclide('O16', 2.0)
    uo2.set_density('g/cm3', 10.5)


    #cladding
    zirconium = openmc.Material(name="zirconium",temperature=900)
    zirconium.add_element('Zr', 1.0)
    zirconium.set_density('g/cm3', 6.6)

    #coolant
    water = openmc.Material(name="h2o")
    water.add_nuclide('H1', 2.0)
    water.add_nuclide('O16', 1.0)
    water.set_density('g/cm3', 0.74)
    water.add_s_alpha_beta('c_H_in_H2O')

    mats = openmc.Materials([uo2, zirconium, water])


    fuel_or = openmc.ZCylinder(r=0.41) #fuel cylinder with outer radius
    clad_ir = openmc.ZCylinder(r=0.42) #clad inner cylinder with inner radius
    clad_or = openmc.ZCylinder(r=0.45) #clad outer cylinder with outer radius

    fuel_region = -fuel_or                #inside the fuel cylinder
    gap_region = +fuel_or & -clad_ir      #outside of fuel cylinder and inside of clad inner cylinder
    clad_region = +clad_ir & -clad_or     #outside of clad inner cylinder and inside of clad outer cylinder

    fuel = openmc.Cell(name='fuel')
    fuel.fill = uo2
    fuel.region = fuel_region

    gap = openmc.Cell(name='air gap')
    gap.region = gap_region

    clad = openmc.Cell(name='clad')
    clad.fill = zirconium
    clad.region = clad_region

    # pitch = 1.26
    #we define the x and y planes with boundary condition
    left = openmc.XPlane(x0=-pitch/2, boundary_type='reflective')
    right = openmc.XPlane(x0=pitch/2, boundary_type='reflective')
    bottom = openmc.YPlane(y0=-pitch/2, boundary_type='reflective')
    top = openmc.YPlane(y0=pitch/2, boundary_type='reflective')

    #outside of left and inside of right, outside of bottom, and inside of top and outside of clad outer cylinder
    water_region = +left & -right & +bottom & -top & +clad_or

    moderator = openmc.Cell(name='moderator')
    moderator.fill = water
    moderator.region = water_region

    root = openmc.Universe(cells=(fuel, gap, clad, moderator))

    geom = openmc.Geometry()
    geom.root_universe = root

    point = openmc.stats.Point((0, 0, 0))
    src = openmc.Source(space=point)

    settings = openmc.Settings()
    settings.source = src
    settings.batches = 100
    settings.inactive = 10
    settings.particles = 500
    #tallies
    T=1200
    k=8.617333262145e-5
    energy_filter = openmc.EnergyFilter([0., 5*k*T, 20.0e6])
    fuel_filter = openmc.CellFilter(fuel)
    moderator_filter = openmc.CellFilter(moderator)
    tally1 = openmc.Tally(1)
    tally1.filters = [fuel_filter,energy_filter]
    tally1.scores = ['absorption','nu-fission']
    
    tally2 = openmc.Tally(2)
    tally2.filters = [moderator_filter,energy_filter]
    tally2.scores = ['absorption']
    tallies = openmc.Tallies([tally1, tally2])
    model = openmc.model.Model(geom, mats, settings,tallies)
    return model

# %% [markdown]
# Now we just have to figure out how to compute $p$ and $f$ from the tallies. First it is best to remind ourselves how to load in the tally results, and you can do some trial and error to figure out these values. Let's run a computation with our model.

# %%
# os.system('rm *h5')
mod=pincell(1.26)
output = mod.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13 17:36:30
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files will be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /root/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /root/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /root/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /root/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /root/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /root/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /root/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading H1 from /root/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading c_H_in_H2O from /root/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.46984
#         2/1    1.46139
#         3/1    1.52836
#         4/1    1.34185
#         5/1    1.46365
#         6/1    1.45308
#         7/1    1.37032
#         8/1    1.31150
#         9/1    1.43759
#        10/1    1.42943
#        11/1    1.22402
#        12/1    1.28047    1.25225 +/- 0.02823
#        13/1    1.46973    1.32474 +/- 0.07430
#        14/1    1.45484    1.35727 +/- 0.06179
#        15/1    1.44189    1.37419 +/- 0.05077
#        16/1    1.32856    1.36659 +/- 0.04214
#        17/1    1.39561    1.37073 +/- 0.03586
#        18/1    1.54104    1.39202 +/- 0.03765
#        19/1    1.45711    1.39925 +/- 0.03398
#        20/1    1.39412    1.39874 +/- 0.03040
#        21/1    1.47720    1.40587 +/- 0.02841
#        22/1    1.36695    1.40263 +/- 0.02613
#        23/1    1.38360    1.40117 +/- 0.02409
#        24/1    1.37732    1.39946 +/- 0.02236
#        25/1    1.42602    1.40123 +/- 0.02089
#        26/1    1.42684    1.40283 +/- 0.01961
#        27/1    1.39425    1.40233 +/- 0.01843
#        28/1    1.41240    1.40289 +/- 0.01738
#        29/1    1.36590    1.40094 +/- 0.01656
#        30/1    1.37741    1.39977 +/- 0.01575
#        31/1    1.43783    1.40158 +/- 0.01509
#        32/1    1.30301    1.39710 +/- 0.01507
#        33/1    1.39399    1.39696 +/- 0.01440
#        34/1    1.40569    1.39733 +/- 0.01379
#        35/1    1.35730    1.39573 +/- 0.01333
#        36/1    1.29883    1.39200 +/- 0.01334
#        37/1    1.36751    1.39109 +/- 0.01286
#        38/1    1.34805    1.38955 +/- 0.01249
#        39/1    1.28087    1.38581 +/- 0.01262
#        40/1    1.35229    1.38469 +/- 0.01224
#        41/1    1.29879    1.38192 +/- 0.01216
#        42/1    1.35502    1.38108 +/- 0.01181
#        43/1    1.57821    1.38705 +/- 0.01291
#        44/1    1.37905    1.38682 +/- 0.01253
#        45/1    1.33569    1.38536 +/- 0.01225
#        46/1    1.37304    1.38501 +/- 0.01191
#        47/1    1.39321    1.38523 +/- 0.01159
particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.38347 +/- 0.00589
#  k-effective (Track-length)  = 1.38021 +/- 0.00733
#  k-effective (Absorption)    = 1.38836 +/- 0.00467
#  Combined k-effective        = 1.38676 +/- 0.00445
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %% [markdown]
# And now load in the tallies. And from there you can perform the necessary operations to obtain $p$ and $f$.

# %%
sp = openmc.StatePoint(output)
tallydf1 = sp.tallies[1].get_pandas_dataframe()
tallydf1
# Out:
#    cell  energy low [eV]  energy high [eV] nuclide       score     mean  \
# 0   193         0.00e+00          5.17e-01   total  absorption 5.61e-01
# 1   193         0.00e+00          5.17e-01   total  nu-fission 1.06e+00
# 2   193         5.17e-01          2.00e+07   total  absorption 3.92e-01
# 3   193         5.17e-01          2.00e+07   total  nu-fission 3.24e-01
#
#    std. dev.
# 0   3.77e-03
# 1   7.11e-03
# 2   1.85e-03
# 3   1.25e-03

# %%
sp = openmc.StatePoint(output)
tallydf2 = sp.tallies[2].get_pandas_dataframe()
tallydf2
# Out:
#    cell  energy low [eV]  energy high [eV] nuclide       score     mean  \
# 0   196         0.00e+00          5.17e-01   total  absorption 3.18e-02
# 1   196         5.17e-01          2.00e+07   total  absorption 6.31e-03
#
#    std. dev.
# 0   2.16e-04
# 1   4.18e-05

# %%
p = 1.0 - tallydf1['mean'][2]/(tallydf1['mean'][1]+tallydf1['mean'][3])
f = tallydf1['mean'][0]/(tallydf1['mean'][0] + tallydf2['mean'][0])

print(p, f)
# Out:
# 0.7156351965424368 0.9462553645075039

# %% [markdown]
# Once we know how to get these quantities we can loop through several pitch values to see how they change with the moderator to fuel ratio!

# %%
pitch=[0.95,1.05,1.15,1.25,1.35,1.45,1.55,1.65,1.75,1.85,1.95,2.05,2.15,2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95]
os.system('rm *h5')
keff=[]
p=[]
f=[]
for pi in pitch:
    #create a model
    #run the model
    #read the statepoint file and the tallies
    mod = pincell(pi)
    output = mod.run()
    sp = openmc.StatePoint(output)
    tallydf1 = sp.tallies[1].get_pandas_dataframe()
    tallydf2 = sp.tallies[2].get_pandas_dataframe()
    
    keff.append(sp.keff.nominal_value)
    p.append(1.0 - tallydf1['mean'][2]/(tallydf1['mean'][1]+tallydf1['mean'][3]))
    f.append(tallydf1['mean'][0]/(tallydf1['mean'][0] + tallydf2['mean'][0]))
    os.system('rm *h5')
# Out:
# /usr/local/lib/python3.9/dist-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1.
#   warn(msg, IDWarning)
# /usr/local/lib/python3.9/dist-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=2.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13 18:45:47
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files will be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /root/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /root/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /root/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /root/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /root/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /root/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /root/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading H1 from /root/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading c_H_in_H2O from /root/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.15823
#         2/1    1.12234
#         3/1    1.02421
#         4/1    0.96270
#         5/1    1.19884
#         6/1    1.09263
#         7/1    1.01968
#         8/1    1.09463
#         9/1    1.05243
#        10/1    1.06598
#        11/1    1.08367
#        12/1    1.10481    1.09424 +/- 0.01057
#        13/1    0.98587    1.05812 +/- 0.03663
#        14/1    1.12007    1.07360 +/- 0.03018
#        15/1    0.96144    1.05117 +/- 0.03240
#        16/1    0.99952    1.04256 +/- 0.02782
#        17/1    0.94860    1.02914 +/- 0.02707
#        64/1    1.14058    1.20495 +/- 0.01001
#        65/1    1.26907    1.20611 +/- 0.00989
#        66/1    1.18712    1.20577 +/- 0.00972
#        67/1    1.14635    1.20473 +/- 0.00961
#        68/1    1.21334    1.20488 +/- 0.00944
#        69/1    1.31626    1.20677 +/- 0.00947
#        70/1    1.28141    1.20801 +/- 0.00939
#        71/1    1.16428    1.20729 +/- 0.00926
#        72/1    1.25756    1.20811 +/- 0.00915
#        73/1    1.33764    1.21016 +/- 0.00924
#        74/1    1.15199    1.20925 +/- 0.00913
#        75/1    1.15213    1.20837 +/- 0.00904
#        76/1    1.28650    1.20956 +/- 0.00898
#        77/1    1.24352    1.21006 +/- 0.00886
#        78/1    1.29245    1.21128 +/- 0.00881
#        79/1    1.25455    1.21190 +/- 0.00870
#        80/1    1.28087    1.21289 +/- 0.00863
#        81/1    1.14551    1.21194 +/- 0.00856
#        82/1    1.29466    1.21309 +/- 0.00852
#        83/1    1.16268    1.21240 +/- 0.00843
#        84/1    1.20959    1.21236 +/- 0.00832
#        85/1    1.26266    1.21303 +/- 0.00823
#        86/1    1.23891    1.21337 +/- 0.00813
#        87/1    1.28751    1.21433 +/- 0.00808
#        88/1    1.22188    1.21443 +/- 0.00798
#        89/1    1.20479    1.21431 +/- 0.00788
#        90/1    1.26517    1.21494 +/- 0.00781
#        91/1    1.17768    1.21448 +/- 0.00772
#        92/1    1.27909    1.21527 +/- 0.00767
#        93/1    1.28654    1.21613 +/- 0.00762
#        94/1    1.27316    1.21681 +/- 0.00756
#        95/1    1.18320    1.21641 +/- 0.00748
#        96/1    1.15364    1.21568 +/- 0.00743
#        97/1    1.18089    1.21528 +/- 0.00736
#        98/1    1.35356    1.21686 +/- 0.00744
#        99/1    1.26796    1.21743 +/- 0.00738
#       100/1    1.19799    1.21721 +/- 0.00730
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8615e-01 seconds
#    Reading cross sections          = 3.4809e-01 seconds
#  Total time in simulation          = 3.9202e-01 seconds
#    Time in transport only          = 3.4593e-01 seconds
#    Time in inactive batches        = 4.0693e-02 seconds
#    Time in active batches          = 3.5133e-01 seconds
#    Time synchronizing fission bank = 2.3558e-03 seconds
#      Sampling source sites         = 1.9370e-03 seconds
#      SEND/RECV source sites        = 1.8700e-04 seconds
#    Time accumulating tallies       = 4.8918e-03 seconds
#    Time writing statepoints        = 3.1631e-02 seconds
#  Total time for finalization       = 1.3492e-03 seconds
#  Total time elapsed                = 7.8218e-01 seconds
#  Calculation Rate (inactive)       = 122871 particles/second
#  Calculation Rate (active)         = 128085 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.21118 +/- 0.00593
#  k-effective (Track-length)  = 1.21721 +/- 0.00730
#  k-effective (Absorption)    = 1.20582 +/- 0.00477
#  Combined k-effective        = 1.20856 +/- 0.00446
#  Leakage Fraction            = 0.00000 +/- 0.00000
# /usr/local/lib/python3.9/dist-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=1.
#   warn(msg, IDWarning)
# /usr/local/lib/python3.9/dist-packages/openmc/mixin.py:70: IDWarning: Another Tally instance already exists with id=2.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.3
#         Git SHA1 | 27cb0dc97960fe6d750eb5a93584a9a0ca532ac8
#        Date/Time | 2025-08-13 18:46:07
#    MPI Processes | 1
#   OpenMP Threads | 16
#
#  Reading model XML file './model.xml' ...
#  WARNING: Other XML file input(s) are present. These files will be ignored in
#           favor of the ./model.xml file.
#  Reading cross sections XML file...
#  Reading U235 from /root/endfb-vii.1-hdf5/neutron/U235.h5
#  Reading U238 from /root/endfb-vii.1-hdf5/neutron/U238.h5
#  Reading O16 from /root/endfb-vii.1-hdf5/neutron/O16.h5
#  Reading Zr90 from /root/endfb-vii.1-hdf5/neutron/Zr90.h5
#  Reading Zr91 from /root/endfb-vii.1-hdf5/neutron/Zr91.h5
#  Reading Zr92 from /root/endfb-vii.1-hdf5/neutron/Zr92.h5
#  Reading Zr94 from /root/endfb-vii.1-hdf5/neutron/Zr94.h5
#  Reading Zr96 from /root/endfb-vii.1-hdf5/neutron/Zr96.h5
#  Reading H1 from /root/endfb-vii.1-hdf5/neutron/H1.h5
#  Reading c_H_in_H2O from /root/endfb-vii.1-hdf5/neutron/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1
#        71/1    1.10357    1.19073 +/- 0.00855
#        72/1    1.22566    1.19129 +/- 0.00843
#        73/1    1.17804    1.19108 +/- 0.00830
#        74/1    1.11629    1.18991 +/- 0.00825
#        75/1    1.13416    1.18906 +/- 0.00817
#        76/1    1.10946    1.18785 +/- 0.00813
#        77/1    1.18113    1.18775 +/- 0.00801
#        78/1    1.25955    1.18881 +/- 0.00796
#        79/1    1.20585    1.18905 +/- 0.00785
#        80/1    1.14302    1.18840 +/- 0.00777
#        81/1    1.15293    1.18790 +/- 0.00767
#        82/1    1.14417    1.18729 +/- 0.00759
#        83/1    1.11174    1.18625 +/- 0.00756
#        84/1    1.20499    1.18651 +/- 0.00746
#        85/1    1.16877    1.18627 +/- 0.00736
#        86/1    1.17395    1.18611 +/- 0.00727
#        87/1    1.17330    1.18594 +/- 0.00717
#        88/1    1.20291    1.18616 +/- 0.00708
#        89/1    1.18938    1.18620 +/- 0.00699
#        90/1    1.15738    1.18584 +/- 0.00691
#        91/1    1.03459    1.18397 +/- 0.00708
#        92/1    1.11148    1.18309 +/- 0.00705
#        93/1    1.13422    1.18250 +/- 0.00699
#        94/1    1.22993    1.18306 +/- 0.00693
#        95/1    1.22743    1.18359 +/- 0.00687
#        96/1    1.11693    1.18281 +/- 0.00683
#        97/1    1.23890    1.18346 +/- 0.00678
#        98/1    1.23596    1.18405 +/- 0.00673
#        99/1    1.14637    1.18363 +/- 0.00667
#       100/1    1.25500    1.18442 +/- 0.00664
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.9620e-01 seconds
#    Reading cross sections          = 3.5019e-01 seconds
#  Total time in simulation          = 4.0344e-01 seconds
#    Time in transport only          = 3.5800e-01 seconds
#    Time in inactive batches        = 2.8365e-02 seconds
#    Time in active batches          = 3.7508e-01 seconds
#    Time synchronizing fission bank = 2.2388e-03 seconds
#      Sampling source sites         = 1.7838e-03 seconds
#      SEND/RECV source sites        = 1.9391e-04 seconds
#    Time accumulating tallies       = 5.0153e-03 seconds
#    Time writing statepoints        = 3.1007e-02 seconds
#  Total time for finalization       = 1.3437e-03 seconds
#  Total time elapsed                = 8.0325e-01 seconds
#  Calculation Rate (inactive)       = 176271 particles/second
#  Calculation Rate (active)         = 119975 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18285 +/- 0.00555
#  k-effective (Track-length)  = 1.18442 +/- 0.00664
#  k-effective (Absorption)    = 1.18738 +/- 0.00493
#  Combined k-effective        = 1.18595 +/- 0.00449
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %% [markdown]
# Finally we are ready to visualize our results and then conclude our findings. Try to summarize with few words the underlying physics what we just discovered here.

# %%
import numpy as np
mfr = (np.array(pitch)**2 - 0.45**2*np.pi)/(0.41**2*np.pi)

plt.figure()
plt.plot(mfr,keff,label='k-inf')
plt.plot(mfr,p,label='p')
plt.plot(mfr,f,label='f')
plt.legend()
plt.xlabel('Moderator to fuel ratio')
plt.show()

# %% [markdown]
# At low values of mfr we dont have a lot of moderator material which means that not a lot of fast neutrons get slwoed down. This results in more neutrons getting captured in resonance energeis which reduces p. More moderator material means more neutrons getting slowed down and scattering dominates over resonance absoprtion.
#
# For f, more moderator meterial means more themrmal neutrons get absorbed in the water instead of the fuel.
